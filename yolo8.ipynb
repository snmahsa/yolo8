# %% [markdown]
# #Prepare Dataset and library

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install kaggle

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content/drive/MyDrive/Yolov8/Kaggle'

# %%
# %cd '/content/drive/MyDrive/Yolov8/Kaggle'
# Out:
# /content/drive/MyDrive/Yolov8/Kaggle

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Yolov8/Kaggle'

# %%
# !kaggle datasets download -d lokeshvloki/animal-dataset-image-with-annotation
# Out:
# ...
#  95% 140M/147M [00:01<00:00, 157MB/s]
# 100% 147M/147M [00:01<00:00, 112MB/s]

# %%
# %%capture
# !unzip /content/drive/MyDrive/Yolov8/Kaggle/animal-dataset-image-with-annotation.zip -d /content/drive/MyDrive/Yolov8/Dataset/

# %%
# %%capture
# !pip install ultralytics

# %%
# %cd '/content/drive/MyDrive/Yolov8'
# Out:
# /content/drive/MyDrive/Yolov8

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Yolov8'

# %%
# %%capture
# !pip install Ipython

# %% [markdown]
# #Train

# %%
import matplotlib.pyplot as plt
from IPython.display import Image as imgshow
import os
from ultralytics import YOLO
import numpy as np
from PIL import Image
import cv2
from google.colab.patches import cv2_imshow

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/Yolov8/Dataset/Animal/animal.yaml epochs=20 imgsz=640
# Out:
# Ultralytics YOLOv8.0.184 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/Yolov8/runs/detect/train3/weights/best.pt  data=/content/drive/MyDrive/Yolov8/Dataset/Animal/animal.yaml
# Out:
# Ultralytics YOLOv8.0.184 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11130228 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/Yolov8/Dataset/Animal/valid/labels.cache... 406 images, 2 backgrounds, 0 corrupt: 100% 408/408 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  31% 8/26 [00:04<00:07,  2.52it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  42% 11/26 [00:05<00:04,  3.70it/s]libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/Yolov8/runs/detect/train3/weights/best.pt  source=/content/drive/MyDrive/Yolov8/Dataset/Animal/valid/images
# Out:
# Ultralytics YOLOv8.0.184 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11130228 parameters, 0 gradients
#
# image 1/408 /content/drive/MyDrive/Yolov8/Dataset/Animal/valid/images/00000009_300resized.png: 640x640 1 Tiger, 16.3ms
# image 2/408 /content/drive/MyDrive/Yolov8/Dataset/Animal/valid/images/00000010_300resized.png: 640x640 1 Tiger, 16.4ms
# libpng warning: iCCP: known incorrect sRGB profile
# image 3/408 /content/drive/MyDrive/Yolov8/Dataset/Animal/valid/images/00000011_300resized.png: 640x640 1 Tiger, 16.3ms
# image 4/408 /content/drive/MyDrive/Yolov8/Dataset/Animal/valid/images/00000015_300resized.png: 640x640 1 Tiger, 16.3ms
# image 5/408 /content/drive/MyDrive/Yolov8/Dataset/Animal/valid/images/00000016_300resized.png: 640x640 1 Tiger, 30.9ms
# image 6/408 /content/drive/MyDrive/Yolov8/Dataset/Animal/valid/images/00000017_300resized.png: 640x640 1 Tiger, 16.4ms
# ...
